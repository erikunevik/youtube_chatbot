# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv()

BASE_URL = f"https://eriks-aichatbot.azurewebsites.net/chatbot/query?code={os.getenv('FUNCTION_APP_API')}"

response = requests.post(BASE_URL, json={"prompt": "Tell me about pandas"})
response
# Out:
# <Response [200]>

# %%
print("STATUS:", response.status_code)
print("TEXT:", response.text)
# Out:
# STATUS: 200
# ...

# %%
response.json()
# Out:
# {'filename': 'pandas_read_excel',
#  'filepath': 'C:\\Users\\eriku\\Desktop\\DataenginerSTI2024-2026\\Github\\Youtube_ragbot\\data\\pandas_read_excel.md',
# ...
